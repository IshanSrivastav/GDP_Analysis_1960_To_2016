# %% [markdown]
# <a href="https://colab.research.google.com/github/IshanSrivastav/GDP_Analysis_1960_To_2016/blob/main/GDP_Analysis_03_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import plotly.express as px
import plotly.offline as pyo

df = pd.read_csv('gdp.csv')

df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %% [markdown]
# ## 1) How many unique Countries Data we're having in the dataset?

# %%
df['Country Name'].nunique() # -> For Count
# Out:
# 256

# %%
df['Country Name'].unique() # -> With Name
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
# ...

# %% [markdown]
# ## 2) How many years of Data we're having for India

# %%
df[df['Country Name'] == "India"]['Year'].nunique() # -> This Will Print Unique Years Of India Like We Have 57 Years Of Data For India
# Out:
# 57

# %% [markdown]
# ## 3) Whats the world GDP in 1969?

# %%
df[(df['Country Name'] == "World") & (df['Year'] == 1969)]
# Out:
#      Country Name Country Code  Year         Value
# 2258        World          WLD  1969  2.690798e+12

# %% [markdown]
# ## 4) Whats the % of GDP growth of India in Year 1994 (*as compare to 1993)?

# %%
# Filter for 'India' and for the years 1993 and 1994
df_pr = df[(df['Country Name'] == 'India') & (df['Year'].isin([1993, 1994]))]

df_pr
# Out:
#      Country Name Country Code  Year         Value
# 6107        India          IND  1993  2.755704e+11
# 6108        India          IND  1994  3.229099e+11

# %%
round(((3229 - 2755) / 2755)*100,2) # which means we had a gdp growth of 17.21 percent in 1994 as compared to 1993 in india.
# Out:
# 17.21

# %% [markdown]
# # Tasks
#
# ### 1) Find GDP Growth of India from 1960 - 2016
# ### 2) Create a new columns named as GDP_Percent which shows the GDP growth of each country for that year
# ### 3) Create a graph of GDP Growth of India from 1960 - 2016

# %%
# Answer To Task - 1 GDP Growth Of India In Each Year From 1960-2016
# Filter the DataFrame for 'India' and for years between 1960 and 2016
df_pr = df[(df['Country Name'] == 'India') & (df['Year'].between(1960, 2016))]

data = df_pr.values

gdp_change = [0]

for i in range(1,len(data)):

  prev = data[i-1][3]
  cur = data[i][3]

  gdp_change.append(round(((cur - prev) / prev)*100,2))

df_pr = df_pr.assign(GDP_Percent = gdp_change)

df_pr
# Out:
#      Country Name Country Code  Year         Value  GDP_Percent
# 6074        India          IND  1960  3.653593e+10         0.00
# 6075        India          IND  1961  3.870910e+10         5.95
# 6076        India          IND  1962  4.159907e+10         7.47
# 6077        India          IND  1963  4.777600e+10        14.85
# 6078        India          IND  1964  5.572687e+10        16.64
# 6079        India          IND  1965  5.876042e+10         5.44
# 6080        India          IND  1966  4.525364e+10       -22.99
# 6081        India          IND  1967  4.946617e+10         9.31
# 6082        India          IND  1968  5.237732e+10         5.89
# 6083        India          IND  1969  5.766833e+10        10.10
# 6084        India          IND  1970  6.158980e+10         6.80
# 6085        India          IND  1971  6.645256e+10         7.90
# 6086        India          IND  1972  7.050991e+10         6.11
# 6087        India          IND  1973  8.437454e+10        19.66
# ...

# %%
# Answer To Task 2 Below Code Is Commented As It Has Been already Include in The Starting.

import os
import pandas as pd
import plotly.express as px
import plotly.offline as pyo

df = pd.read_csv('gdp.csv')

final_data = []

for country_name in df['Country Name'].unique():

  df_pr = df[df['Country Name'] == country_name]

  data = df_pr.values

  gdp_change = [0]

  for i in range(1,len(data)):

    prev = data[i-1][3]
    cur = data[i][3]

    gdp_change.append(round(((cur - prev) / prev)*100,2))

  df_pr = df_pr.assign(GDP_Percent = gdp_change)
  final_data.append(df_pr)

df = pd.concat(final_data, axis = 0)

# %%
df
# Out:
#       Country Name Country Code  Year         Value  GDP_Percent
# 0       Arab World          ARB  1968  2.576068e+10         0.00
# 1       Arab World          ARB  1969  2.843420e+10        10.38
# 2       Arab World          ARB  1970  3.138550e+10        10.38
# 3       Arab World          ARB  1971  3.642691e+10        16.06
# 4       Arab World          ARB  1972  4.331606e+10        18.91
# ...            ...          ...   ...           ...          ...
# 11502     Zimbabwe          ZWE  2012  1.424249e+10        17.72
# 11503     Zimbabwe          ZWE  2013  1.545177e+10         8.49
# 11504     Zimbabwe          ZWE  2014  1.589105e+10         2.84
# 11505     Zimbabwe          ZWE  2015  1.630467e+10         2.60
# 11506     Zimbabwe          ZWE  2016  1.661996e+10         1.93
#
# [11507 rows x 5 columns]

# %%
# Answer For Task 3 With Graph
df_pr = df[df['Country Name'] == 'India']

fig = px.line(df_pr, x = 'Year', y = 'Value', title = 'India GDP Analysis')

fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
